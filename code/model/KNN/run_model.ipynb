# %% [markdown]
# # 모델 불러와 실행

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

rs = 42

def prepare_data(df):
    X = df.drop(columns=['target'])
    y = df['target']
    
    # X_train, X_test, y_train, y_test
    return train_test_split(X, y, stratify=y, test_size=0.2 , random_state=rs)

# %%
import joblib

# 모델 불러오기
model = joblib.load('kNN_trained_model.pkl')

# %%
data = pd.read_csv("../dataset/SAM_result/concat_image_rgb_info.csv")

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134328 entries, 0 to 134327
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   imagedirectory  134328 non-null  object
#  1   file_name       134328 non-null  object
#  2   origin_r        134328 non-null  float64
#  3   origin_g        134328 non-null  float64
#  4   origin_b        134328 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 5.1+ MB
#                imagedirectory         file_name  origin_r  origin_g  origin_b
# 0  F0016-C101-20210910-125907  image_mask_1.png  0.351564  0.406222  0.242214
# 1  F0016-C101-20210910-125907  image_mask_2.png  0.367803  0.445607  0.186590
# 2  F0016-C101-20210910-165907  image_mask_3.png  0.367177  0.417558  0.215264
# 3  F0016-C101-20210910-165907  image_mask_5.png  0.330916  0.336561  0.332523
# 4  F0016-C101-20210910-165907  image_mask_6.png  0.322733  0.347697  0.329570

# %%
X = data[["origin_r", "origin_g"]]

# %%
data['pred_growth'] = model.predict(X)

# %%
data
# Out:
#                     imagedirectory          file_name  origin_r  origin_g  \
# 0       F0016-C101-20210910-125907   image_mask_1.png  0.351564  0.406222
# 1       F0016-C101-20210910-125907   image_mask_2.png  0.367803  0.445607
# 2       F0016-C101-20210910-165907   image_mask_3.png  0.367177  0.417558
# 3       F0016-C101-20210910-165907   image_mask_5.png  0.330916  0.336561
# 4       F0016-C101-20210910-165907   image_mask_6.png  0.322733  0.347697
# ...                            ...                ...       ...       ...
# 134323  F0017-C101-20240403-084305  image_mask_10.png  0.347078  0.389511
# 134324  F0017-C101-20240403-084305  image_mask_21.png  0.365075  0.348896
# 134325  F0017-C101-20240403-084305   image_mask_9.png  0.342480  0.374930
# 134326  F0017-C101-20240403-084305  image_mask_11.png  0.340997  0.363187
# 134327  F0017-C101-20240403-084305  image_mask_13.png  0.394317  0.346565
#
#         origin_b pred_growth
# 0       0.242214      unripe
# ...

# %%
data.to_csv("../dataset/SAM_result/concat_image_rgb_info_predicted.csv", index=False)

# %%
# import os
# from PIL import Image
# import matplotlib.pyplot as plt

# def visualize_image(image_path):
#     # 이미지 열기
#     image = Image.open(image_path)

#     # 이미지 시각화
#     plt.imshow(image)
#     plt.axis('off')  # 축 숨기기
#     plt.show()

# for i in data.index:
#     imagedirectory = data.loc[i, "imagedirectory"]
#     image_path = os.path.join("../dataset/SAM_result", imagedirectory[:5], imagedirectory[6:10], imagedirectory, "masks", data.loc[i, "file_name"])

#     print(f"<{image_path}>")
#     print(data.loc[i, "predicted_target"])

#     visualize_image(image_path)
